# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
print('Hari ini saya mulai belajar Python')
# Out:
# Hari ini saya mulai belajar Python

# %%
nama_depan = "Diva"
nama_tengah = " Felizia "
nama_belakang = "Bagindo"
print(nama_depan + nama_tengah + nama_belakang)
# Out:
# Diva Felizia Bagindo

# %%
nama = input('Siapakah aku?')
kegiatan = input('Apakah proker yang sedang berjalan saat ini, ' + nama +"? ")
print("Semangat "+ kegiatan +" nya yah, " + nama + "!")
# Out:
# Siapakah aku? Diva Felizia Bagindo
# Apakah proker yang sedang berjalan saat ini, Diva Felizia Bagindo?  ANNIVERSARY HIMATIKA 2024
# Semangat ANNIVERSARY HIMATIKA 2024 nya yah, Diva Felizia Bagindo!

# %%
ikan_di_aquarium = input("Berapakah jumlah ikan di aquarium itu? ")
ikan_di_kolam = input("Berapakah jumlah ikan di kolam itu? ")
total_ikan = int(ikan_di_aquarium) + int(ikan_di_kolam)
print("Total ikan itu adalah "+ str(total_ikan))
# Out:
# Berapakah jumlah ikan di aquarium itu?  40
# Berapakah jumlah ikan di kolam itu?  50
# Total ikan itu adalah 90

# %%
sisi_sejajar_a = input("Masukkan panjang sisi sejajar pertama dalam cm: ")
sisi_sejajar_b = input("Masukkan panjang sisi sejajar kedua dalam cm: ")
tinggi = input("Masukkan tinggi dalam cm: ")
luas_trapesium = int(sisi_sejajar_a) + int(sisi_sejajar_b) * int(tinggi)/ int(2)
print("Luas trapesium adalah: ", luas_trapesium, "cm^2")
# Out:
# Masukkan panjang sisi sejajar pertama dalam cm:  20
# Masukkan panjang sisi sejajar kedua dalam cm:  10
# Masukkan tinggi dalam cm:  2
# Luas trapesium adalah:  30.0 cm^2

# %%
kontrakan_terisi = 15
harga_kontrakan = 15000000
pemasukkan_kontrakan = kontrakan_terisi*harga_kontrakan
print(kontrakan_terisi)
print(harga_kontrakan)
print(pemasukkan_kontrakan)
# Out:
# 15
# 15000000
# 225000000

# %%
print('Selamat bergabung pada Cek Nilai Algoritma')
individu = input("Masukkan niai tugas individu: ")
kelompok = input("Masukkan nilai tugas kelompok: ")
kehadiran = input("Masukkan nilai kehadiran: ")
kuis = input ("Masukkan nilai kuis: ")
uts = input("Masukkan nilai uts: ")
uas = input("Masukkan nilai uas: ")
jumlah = (float(individu)*float(0.15)) + (float(kelompok)*float(0.20)) + (float(kehadiran)*float(0.05)) + (float(kuis)*float(0.10)) + (float(uts)*float(0.25)) + (float(uas)*float(0.25))
rata = float(jumlah) / 6
print("Jadi nilai yang diperoleh pada mata kuliah Algoritma adalah: " + str(jumlah))
# Out:
# Selamat bergabung pada Cek Nilai Algoritma
# Masukkan niai tugas individu:  83
# Masukkan nilai tugas kelompok:  85
# Masukkan nilai kehadiran:  100
# Masukkan nilai kuis:  84
# Masukkan nilai uts:  87
# Masukkan nilai uas:  88
# Jadi nilai yang diperoleh pada mata kuliah Algoritma adalah: 86.6

# %%
suhu_dalam_celcius = input("Masukkan suhu dalam Celcius ")
suhu_dalam_fahrenheit = (float(suhu_dalam_celcius)*float(9/5)+ float(32))
print("Suhu dalam Fahrenheit ", suhu_dalam_fahrenheit)
# Out:
# Masukkan suhu dalam Celcius  20
# Suhu dalam Fahrenheit  68.0

# %%
kuliah = input("Diva kuliah dimana? ")
prodi = input("Program studi nya apa? ")
print("Waww seru banget kuliah "+ prodi +", Diva yang semangat kuliahnya ya! ")
# Out:
# Diva kuliah dimana?  Universitas Udayana
# Program studi nya apa?  Matematika
# Waww seru banget kuliah Matematika, Diva yang semangat kuliahnya ya!

# %%
bilangan = input("Masukkan suatu bilangan: ")
hasil_pangkat_dua = (float(bilangan)**float(2))
print("Hasil pangkat dua dari", bilangan, "adalah:", hasil_pangkat_dua)
# Out:
# Masukkan suatu bilangan:  6
# Hasil pangkat dua dari 6 adalah: 36.0

# %%
bilangan = [3,6,9,12,15,17]
nilai_maksimum = float(max(bilangan))
print("Nilai maksimum dari bilangan", bilangan, "adalah:", nilai_maksimum)
# Out:
# Nilai maksimum dari bilangan [3, 6, 9, 12, 15, 17] adalah: 17.0

# %%
print('Biodata Karyawan Hotel Mercure Resort Sanur Tahun 2024')
nama = input('Nama : ')
alamat = input('Alamat : ')
umur = input('Umur : ')
# mencetak isi variabel
print(nama)
print(alamat)
print(umur)
# Out:
# Biodata Karyawan Hotel Mercure Resort Sanur Tahun 2024
# Nama :  Ajeng Kristiani
# Alamat :  Jln. Kendedes NO. 5 A Kuta
# Umur :  45
# Ajeng Kristiani
# Jln. Kendedes NO. 5 A Kuta
# 45

# %%
a = 80
b = 20
c = a-b
print(c)
# Out:
# 60

# %%
jumlah_boneka = 38
harga_boneka = 150000
print(jumlah_boneka)
print(harga_boneka)
print(jumlah_boneka * harga_boneka)
# Out:
# 38
# 150000
# 5700000

# %%
jumlah_peserta = 20
biaya_pendaftaran = 50000
print(jumlah_peserta)
print(biaya_pendaftaran)
print(jumlah_peserta * biaya_pendaftaran)
# Out:
# 20
# 50000
# 1000000

# %%
nama_barang = input('Masukkan nama barang: ')
harga_barang = input('Masukkan harga barang: ')
jumlah_barang = input('Masukkan jumlah barang: ')
total_harga = int(harga_barang) * int(jumlah_barang)
print("Anda telah membeli", jumlah_barang, nama_barang, "dengan total harga Rp", total_harga)
# Out:
# Masukkan nama barang:  Sepatu
# Masukkan harga barang:  350000
# Masukkan jumlah barang:  3
# Anda telah membeli 3 Sepatu dengan total harga Rp 1050000
